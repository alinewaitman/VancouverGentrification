# %%
import pandas as pd

# %%
df_score = pd.read_csv("df_score.csv")

df_score.head()
# Out:
#                  AREA  AVG_INCOME_2006  AVG_VALUE_DWELLINGS_2006  \
# 0       Arbutus-Ridge            48496                    903780
# 1            Downtown            43365                    563128
# 2   Dunbar-Southlands            59270                    985837
# 3            Fairview            45491                    430372
# 4  Grandview-Woodland            26713                    416736
#
#    POSTSECONDARY_PCT_2006  MANAGEMENT_PCT_2006  AVG_INCOME_2016  \
# 0                0.652721             0.162296            62675
# 1                0.685047             0.175480            63251
# 2                0.704161             0.163677            78117
# 3                0.760833             0.142999            61627
# 4                0.546234             0.075482            42896
#
#    AVG_VALUE_DWELLINGS_2016  POSTSECONDARY_PCT_2016  MANAGEMENT_PCT_2016  \
# 0                   2500033                0.649560             0.193358
# 1                    941493                0.767143             0.177683
# 2                   3026785                0.691400             0.176039
# 3                    761230                0.792365             0.138007
# 4                    899002                0.625699             0.100157
#
#    SCORE_2006  SCORE_2016
# 0    0.031587    1.742374
# 1   -0.246712    0.598705
# 2    0.401332    2.473002
# 3   -0.342041    0.283964
# 4   -1.341465   -0.396126

# %%
#rank areas based on their scores

df_score["RANK_2006"] = df_score["SCORE_2006"].rank(ascending=False)
df_score["RANK_2016"] = df_score["SCORE_2016"].rank(ascending=False)

df_score.head()
# Out:
#                  AREA  AVG_INCOME_2006  AVG_VALUE_DWELLINGS_2006  \
# 0       Arbutus-Ridge            48496                    903780
# 1            Downtown            43365                    563128
# 2   Dunbar-Southlands            59270                    985837
# 3            Fairview            45491                    430372
# 4  Grandview-Woodland            26713                    416736
#
#    POSTSECONDARY_PCT_2006  MANAGEMENT_PCT_2006  AVG_INCOME_2016  \
# 0                0.652721             0.162296            62675
# 1                0.685047             0.175480            63251
# 2                0.704161             0.163677            78117
# 3                0.760833             0.142999            61627
# 4                0.546234             0.075482            42896
#
#    AVG_VALUE_DWELLINGS_2016  POSTSECONDARY_PCT_2016  MANAGEMENT_PCT_2016  \
# 0                   2500033                0.649560             0.193358
# 1                    941493                0.767143             0.177683
# 2                   3026785                0.691400             0.176039
# 3                    761230                0.792365             0.138007
# 4                    899002                0.625699             0.100157
#
#    SCORE_2006  SCORE_2016  RANK_2006  RANK_2016
# 0    0.031587    1.742374        5.0        5.0
# 1   -0.246712    0.598705        8.0        9.0
# 2    0.401332    2.473002        4.0        2.0
# 3   -0.342041    0.283964       10.0       11.0
# 4   -1.341465   -0.396126       17.0       15.0

# %%
#capturing rank changes

df_score["RANK_CHANGE"] = df_score["RANK_2006"] - df_score["RANK_2016"]

df_score.head()
# Out:
#                  AREA  AVG_INCOME_2006  AVG_VALUE_DWELLINGS_2006  \
# 0       Arbutus-Ridge            48496                    903780
# 1            Downtown            43365                    563128
# 2   Dunbar-Southlands            59270                    985837
# 3            Fairview            45491                    430372
# 4  Grandview-Woodland            26713                    416736
#
#    POSTSECONDARY_PCT_2006  MANAGEMENT_PCT_2006  AVG_INCOME_2016  \
# 0                0.652721             0.162296            62675
# 1                0.685047             0.175480            63251
# 2                0.704161             0.163677            78117
# 3                0.760833             0.142999            61627
# 4                0.546234             0.075482            42896
#
#    AVG_VALUE_DWELLINGS_2016  POSTSECONDARY_PCT_2016  MANAGEMENT_PCT_2016  \
# 0                   2500033                0.649560             0.193358
# 1                    941493                0.767143             0.177683
# 2                   3026785                0.691400             0.176039
# 3                    761230                0.792365             0.138007
# 4                    899002                0.625699             0.100157
#
#    SCORE_2006  SCORE_2016  RANK_2006  RANK_2016  RANK_CHANGE
# 0    0.031587    1.742374        5.0        5.0          0.0
# 1   -0.246712    0.598705        8.0        9.0         -1.0
# 2    0.401332    2.473002        4.0        2.0          2.0
# 3   -0.342041    0.283964       10.0       11.0         -1.0
# 4   -1.341465   -0.396126       17.0       15.0          2.0

# %%
# descriptive statistics for rank changes

df_score["RANK_CHANGE"].describe()
# Out:
# count    22.000000
# mean      0.000000
# std       1.799471
# min      -4.000000
# 25%      -1.000000
# 50%       0.000000
# 75%       1.000000
# max       3.000000
# Name: RANK_CHANGE, dtype: float64

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

df_score[["RANK_CHANGE"]].boxplot()
# Out:
# <Axes: >

# %%
# calculate rank changes z-scores

from scipy.stats import zscore

df_score["Z_SCORE"] = df_score[["RANK_CHANGE"]].apply(zscore)

# %%
# assign area status based on z-scores of rank changes (z<-1: area in decline (dec); -1<z<1: stable area (stb); z>1: area in ascension (asc))

df_score["STATUS"] = "stb"

for i in range(len(df_score)):
    if df_score["Z_SCORE"][i] > 1:
        df_score["STATUS"][i] = "asc"
    elif df_score["Z_SCORE"][i] < -1:
        df_score["STATUS"][i] = "dec"
        
df_score
# Out:
# /var/folders/x2/yktmn0x55vb6r1j47trjb5600000gq/T/ipykernel_33934/3630606579.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_score["STATUS"][i] = "asc"
# /var/folders/x2/yktmn0x55vb6r1j47trjb5600000gq/T/ipykernel_33934/3630606579.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_score["STATUS"][i] = "dec"
#                         AREA  AVG_INCOME_2006  AVG_VALUE_DWELLINGS_2006  \
# 0              Arbutus-Ridge            48496                    903780
# 1                   Downtown            43365                    563128
# 2          Dunbar-Southlands            59270                    985837
# 3                   Fairview            45491                    430372
# 4         Grandview-Woodland            26713                    416736
# 5           Hastings-Sunrise            26916                    548064
# 6   Kensington-Cedar Cottage            25757                    538034
# 7                 Kerrisdale            66543                   1115764
# 8                  Killarney            29210                    502674
# 9                  Kitsilano            45444                    642914
# 10                   Marpole            30099                    654299
# 11            Mount Pleasant            30021                    404175
# 12                  Oakridge            38465                    883621
# 13       Renfrew-Collingwood            25102                    494185
# 14                Riley Park            33588                    635018
# 15               Shaughnessy           126310                   1422043
# 16              South Cambie            42155                    737285
# 17                Strathcona            18434                    459923
# 18                    Sunset            24322                    581122
# 19       Victoria-Fraserview            25669                    607081
# 20                  West End            35016                    406894
# 21           West Point Grey            62018                   1078609
#
#     POSTSECONDARY_PCT_2006  MANAGEMENT_PCT_2006  AVG_INCOME_2016  \
# 0                 0.652721             0.162296            62675
# 1                 0.685047             0.175480            63251
# 2                 0.704161             0.163677            78117
# 3                 0.760833             0.142999            61627
# 4                 0.546234             0.075482            42896
# 5                 0.448524             0.069781            38258
# 6                 0.460356             0.065291            38411
# 7                 0.674839             0.170501            77248
# 8                 0.547803             0.087299            39013
# 9                 0.754139             0.137262            63092
# 10                0.621669             0.099764            39020
# 11                0.629692             0.074817            54260
# 12                0.602746             0.182983            46515
# 13                0.466805             0.064372            33360
# 14                0.627054             0.102204            53060
# 15                0.687458             0.183742           118668
# 16                0.728063             0.124848            65459
# 17                0.371542             0.060897            31534
# 18                0.454719             0.053333            34212
# 19                0.451448             0.077002            34298
# 20                0.707193             0.118483            47253
# 21                0.732394             0.150376            82042
#
#     AVG_VALUE_DWELLINGS_2016  POSTSECONDARY_PCT_2016  MANAGEMENT_PCT_2016  \
# 0                    2500033                0.649560             0.193358
# 1                     941493                0.767143             0.177683
# 2                    3026785                0.691400             0.176039
# 3                     761230                0.792365             0.138007
# 4                     899002                0.625699             0.100157
# 5                    1266054                0.470078             0.090885
# 6                    1214877                0.521713             0.079011
# 7                    2879632                0.660862             0.157936
# 8                    1097209                0.544681             0.095779
# 9                    1327707                0.766710             0.141397
# 10                   1695892                0.604863             0.109538
# 11                    803459                0.747134             0.130235
# 12                   2414767                0.614579             0.157803
# 13                   1099509                0.482165             0.075880
# 14                   1695195                0.659636             0.111785
# 15                   3247312                0.697105             0.197970
# 16                   1907007                0.718126             0.134768
# 17                    845567                0.467650             0.104857
# 18                   1456880                0.484523             0.068734
# 19                   1441615                0.446861             0.075969
# 20                    670773                0.748296             0.131673
# 21                   2830724                0.717067             0.132716
#
#     SCORE_2006  SCORE_2016  RANK_2006  RANK_2016  RANK_CHANGE   Z_SCORE STATUS
# 0     0.031587    1.742374        5.0        5.0          0.0  0.000000    stb
# 1    -0.246712    0.598705        8.0        9.0         -1.0 -0.568796    stb
# 2     0.401332    2.473002        4.0        2.0          2.0  1.137593    asc
# 3    -0.342041    0.283964       10.0       11.0         -1.0 -0.568796    stb
# 4    -1.341465   -0.396126       17.0       15.0          2.0  1.137593    asc
# 5    -1.395032   -0.458540       18.0       17.0          1.0  0.568796    stb
# 6    -1.429865   -0.474513       19.0       19.0          0.0  0.000000    stb
# 7     0.645385    2.214694        2.0        4.0         -2.0 -1.137593    dec
# 8    -1.166883   -0.451555       15.0       16.0         -1.0 -0.568796    stb
# 9    -0.206194    0.748853        7.0        8.0         -1.0 -0.568796    stb
# 10   -0.867346    0.175739       13.0       12.0          1.0  0.568796    stb
# 11   -1.166870    0.066502       14.0       13.0          1.0  0.568796    stb
# 12   -0.175314    1.133386        6.0        7.0         -1.0 -0.568796    stb
# 13   -1.473635   -0.742458       20.0       21.0         -1.0 -0.568796    stb
# 14   -0.791940    0.555405       12.0       10.0          2.0  1.137593    asc
# 15    2.213010    3.598784        1.0        1.0          0.0  0.000000    stb
# 16   -0.289506    1.166951        9.0        6.0          3.0  1.706389    asc
# 17   -1.790655   -0.880329       22.0       22.0          0.0  0.000000    stb
# 18   -1.484803   -0.464469       21.0       18.0          3.0  1.706389    asc
# 19   -1.338115   -0.497219       16.0       20.0         -4.0 -2.275186    dec
# 20   -0.761557   -0.178527       11.0       14.0         -3.0 -1.706389    dec
# 21    0.515929    2.246066        3.0        3.0          0.0  0.000000    stb

# %%
# check size of different area status

df_score.groupby(df_score["STATUS"]).size()
# Out:
# STATUS
# asc     5
# dec     3
# stb    14
# dtype: int64

# %%
df_score.to_csv('score_analysis.csv')
